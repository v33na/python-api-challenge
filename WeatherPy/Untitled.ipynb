# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
# Import API key
#from api_keys import api_key
gkey ="AIzaSyAUZt50ZdS_fhQO14NDUerD0hwCFp7wciY"
wkey ="e19cb5e147f5fe43ae70746d48842921"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 625

# %% [markdown]
# Perform API Calls Perform a weather check on each city using a series of successive API calls. Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + wkey

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []
counter = 0
# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")
#Loop through the cities in the city list 
for city in cities:  
    #target_url = url+city+"&appid="+ wkey
    # Try statement to append calls where value is found 
    #try: 
    response = requests.get(f"{url}&q={city}").json()
    print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# Beginning Data Retrieval
# -------------------------------
# {
#     "base": "stations",
#     "clouds": {
#         "all": 4
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -35.36,
#         "lon": 150.48
#     },
#     "dt": 1571075522,
#     "id": 2145554,
#     "main": {
#         "humidity": 93,
#         "pressure": 1012,
#         "temp": 51.39,
#         "temp_max": 51.8,
#         "temp_min": 51.01
#     },
#     "name": "Ulladulla",
#     "sys": {
#         "country": "AU",
#         "id": 9594,
#         "sunrise": 1571080566,
#         "sunset": 1571127098,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 300,
#         "speed": 3.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.23,
#         "lon": -63.6
#     },
#     "dt": 1571075522,
#     "id": 5972291,
#     "main": {
#         "humidity": 87,
#         "pressure": 1019,
#         "temp": 50,
#         "temp_max": 50,
#         "temp_min": 50
#     },
#     "name": "Havre-Saint-Pierre",
#     "sys": {
#         "country": "CA",
#         "id": 812,
#         "sunrise": 1571049262,
#         "sunset": 1571088372,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 14484,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "gust": 18.34,
#         "speed": 10.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.21,
#         "lon": -159.78
#     },
#     "dt": 1571075378,
#     "id": 4035715,
#     "main": {
#         "humidity": 88,
#         "pressure": 1015,
#         "temp": 71.6,
#         "temp_max": 71.6,
#         "temp_min": 71.6
#     },
#     "name": "Avarua",
#     "sys": {
#         "country": "CK",
#         "id": 7271,
#         "sunrise": 1571069311,
#         "sunset": 1571114482,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 4.7
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 18
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 34.45,
#         "lon": 40.92
#     },
#     "dt": 1571075523,
#     "id": 174448,
#     "main": {
#         "grnd_level": 995.43,
#         "humidity": 14,
#         "pressure": 1018,
#         "sea_level": 1018,
#         "temp": 72.05,
#         "temp_max": 72.05,
#         "temp_min": 72.05
#     },
#     "name": "Abu Kamal",
#     "sys": {
#         "country": "SY",
#         "sunrise": 1571023218,
#         "sunset": 1571064255
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "speed": 2.43
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.12,
#         "lon": -134.97
#     },
#     "dt": 1571075344,
#     "id": 4030556,
#     "main": {
#         "grnd_level": 1019.89,
#         "humidity": 82,
#         "pressure": 1020,
#         "sea_level": 1020,
#         "temp": 72.77,
#         "temp_max": 72.77,
#         "temp_min": 72.77
#     },
#     "name": "Rikitea",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1571063280,
#         "sunset": 1571108606
#     },
#     "timezone": -32400,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 64,
#         "speed": 9.68
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 91
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.19,
#         "lon": 168.86
#     },
#     "dt": 1571075307,
#     "id": 6201424,
#     "main": {
#         "humidity": 94,
#         "pressure": 1013,
#         "temp": 48.99,
#         "temp_max": 48.99,
#         "temp_min": 48.99
#     },
#     "name": "Mataura",
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1571075445,
#         "sunset": 1571123398,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 35,
#         "gust": 7,
#         "speed": 3
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.6,
#         "lon": 73.08
#     },
#     "dt": 1571075315,
#     "id": 1282256,
#     "main": {
#         "grnd_level": 1011.14,
#         "humidity": 85,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 79.97,
#         "temp_max": 79.97,
#         "temp_min": 79.97
#     },
#     "name": "Hithadhoo",
#     "rain": {
#         "3h": 2.125
#     },
#     "sys": {
#         "country": "MV",
#         "sunrise": 1571014198,
#         "sunset": 1571057841
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 146,
#         "speed": 15.24
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 10
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -35.71,
#         "lon": 150.18
#     },
#     "dt": 1571075524,
#     "id": 2176639,
#     "main": {
#         "humidity": 93,
#         "pressure": 1010,
#         "temp": 51.01,
#         "temp_max": 51.01,
#         "temp_min": 51.01
#     },
#     "name": "Batemans Bay",
#     "sys": {
#         "country": "AU",
#         "id": 2010627,
#         "sunrise": 1571080618,
#         "sunset": 1571127190,
#         "type": 3
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 247,
#         "gust": 4,
#         "speed": 1.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.64,
#         "lon": 115.35
#     },
#     "dt": 1571075286,
#     "id": 2075265,
#     "main": {
#         "humidity": 61,
#         "pressure": 1014,
#         "temp": 41.04,
#         "temp_max": 42.01,
#         "temp_min": 39
#     },
#     "name": "Busselton",
#     "sys": {
#         "country": "AU",
#         "id": 2011706,
#         "sunrise": 1571089084,
#         "sunset": 1571135440,
#         "type": 3
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 176,
#         "speed": 9.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.16,
#         "lon": -70.91
#     },
#     "dt": 1571075525,
#     "id": 3874787,
#     "main": {
#         "humidity": 41,
#         "pressure": 1026,
#         "temp": 55.89,
#         "temp_max": 57.2,
#         "temp_min": 53.6
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1571045997,
#         "sunset": 1571095145,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 27.51
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 79
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.56,
#         "lon": -96.99
#     },
#     "dt": 1571075526,
#     "id": 5961417,
#     "main": {
#         "humidity": 90,
#         "pressure": 1013,
#         "temp": 39.47,
#         "temp_max": 39.99,
#         "temp_min": 39
#     },
#     "name": "Husavik",
#     "sys": {
#         "country": "CA",
#         "id": 19218,
#         "sunrise": 1571057310,
#         "sunset": 1571096348,
#         "type": 3
#     },
#     "timezone": -18000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 302,
#         "gust": 5.01,
#         "speed": 4
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 20.87,
#         "lon": -156.68
#     },
#     "dt": 1571075526,
#     "id": 5849996,
#     "main": {
#         "humidity": 73,
#         "pressure": 1015,
#         "temp": 76.57,
#         "temp_max": 78.8,
#         "temp_min": 73
#     },
#     "name": "Lahaina",
#     "sys": {
#         "country": "US",
#         "id": 7851,
#         "sunrise": 1571070093,
#         "sunset": 1571112213,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "gust": 17.22,
#         "speed": 11.41
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 30
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -5.56,
#         "lon": -80.82
#     },
#     "dt": 1571075526,
#     "id": 3691954,
#     "main": {
#         "grnd_level": 1011.64,
#         "humidity": 90,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 60.89,
#         "temp_max": 60.89,
#         "temp_min": 60.89
#     },
#     "name": "Sechura",
#     "sys": {
#         "country": "PE",
#         "sunrise": 1571050956,
#         "sunset": 1571094942
#     },
#     "timezone": -18000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 242,
#         "speed": 15.97
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.14,
#         "lon": 80.23
#     },
#     "dt": 1571075526,
#     "id": 1264527,
#     "main": {
#         "humidity": 88,
#         "pressure": 1011,
#         "temp": 78.8,
#         "temp_max": 78.8,
#         "temp_min": 78.8
#     },
#     "name": "Madhavaram",
#     "sys": {
#         "country": "IN",
#         "id": 9218,
#         "sunrise": 1571012945,
#         "sunset": 1571055662,
#         "type": 1
#     },
#     "timezone": 19800,
#     "visibility": 4000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 11.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.74,
#         "lon": -90.35
#     },
#     "dt": 1571075264,
#     "id": 3652764,
#     "main": {
#         "humidity": 53,
#         "pressure": 1014,
#         "temp": 74.17,
#         "temp_max": 77,
#         "temp_min": 71.01
#     },
#     "name": "Puerto Ayora",
#     "sys": {
#         "country": "EC",
#         "id": 8521,
#         "sunrise": 1571053409,
#         "sunset": 1571097063,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "speed": 9.17
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.58,
#         "lon": 149.07
#     },
#     "dt": 1571075410,
#     "id": 2175403,
#     "main": {
#         "grnd_level": 994.23,
#         "humidity": 83,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 66.29,
#         "temp_max": 66.29,
#         "temp_min": 66.29
#     },
#     "name": "Bluff",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1571081479,
#         "sunset": 1571126862
#     },
#     "timezone": 36000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 262,
#         "speed": 3.65
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.35,
#         "lon": -158.09
#     },
#     "dt": 1571075527,
#     "id": 5850554,
#     "main": {
#         "humidity": 78,
#         "pressure": 1015,
#         "temp": 78.26,
#         "temp_max": 80.6,
#         "temp_min": 75
#     },
#     "name": "Makakilo City",
#     "sys": {
#         "country": "US",
#         "id": 7878,
#         "sunrise": 1571070449,
#         "sunset": 1571112532,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 83,
#         "speed": 6.58
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.61,
#         "lon": -37.64
#     },
#     "dt": 1571075528,
#     "id": 3424607,
#     "main": {
#         "humidity": 64,
#         "pressure": 1006,
#         "temp": 35.6,
#         "temp_max": 35.6,
#         "temp_min": 35.6
#     },
#     "name": "Tasiilaq",
#     "sys": {
#         "country": "GL",
#         "id": 81,
#         "sunrise": 1571044854,
#         "sunset": 1571080321,
#         "type": 1
#     },
#     "timezone": -7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "gust": 29.97,
#         "speed": 18.34
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39.45,
#         "lon": 22.34
#     },
#     "dt": 1571074993,
#     "id": 262462,
#     "main": {
#         "humidity": 93,
#         "pressure": 1020,
#         "temp": 65.46,
#         "temp_max": 68,
#         "temp_min": 62.6
#     },
#     "name": "Saint George",
#     "sys": {
#         "country": "GR",
#         "id": 6607,
#         "sunrise": 1571027929,
#         "sunset": 1571068460,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 136,
#         "speed": 4.49
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.97,
#         "lon": 76.18
#     },
#     "dt": 1571075529,
#     "id": 1270260,
#     "main": {
#         "grnd_level": 987.24,
#         "humidity": 37,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 79.07,
#         "temp_max": 79.07,
#         "temp_min": 79.07
#     },
#     "name": "Jatai",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1571014510,
#         "sunset": 1571056041
#     },
#     "timezone": 19800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 111,
#         "speed": 6.67
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 54
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 73.51,
#         "lon": 80.55
#     },
#     "dt": 1571075531,
#     "id": 1507390,
#     "main": {
#         "grnd_level": 1007.8,
#         "humidity": 94,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 29.03,
#         "temp_max": 29.03,
#         "temp_min": 29.03
#     },
#     "name": "Dikson",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571105319,
#         "sunset": 1571135906
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 53,
#         "speed": 14.9
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -7.59,
#         "lon": -35.1
#     },
#     "dt": 1571075531,
#     "id": 3401830,
#     "main": {
#         "humidity": 74,
#         "pressure": 1012,
#         "temp": 81.54,
#         "temp_max": 82.4,
#         "temp_min": 80.6
#     },
#     "name": "Condado",
#     "sys": {
#         "country": "BR",
#         "id": 8391,
#         "sunrise": 1571039915,
#         "sunset": 1571084041,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 130,
#         "speed": 16.11
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.42,
#         "lon": -173.23
#     },
#     "dt": 1571075414,
#     "id": 4031574,
#     "main": {
#         "grnd_level": 967.28,
#         "humidity": 93,
#         "pressure": 996,
#         "sea_level": 996,
#         "temp": 31.19,
#         "temp_max": 31.19,
#         "temp_min": 31.19
#     },
#     "name": "Provideniya",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571163834,
#         "sunset": 1571199187
#     },
#     "timezone": 43200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 79,
#         "speed": 6.83
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 50
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.42,
#         "lon": 19.24
#     },
#     "dt": 1571075275,
#     "id": 3366880,
#     "main": {
#         "humidity": 79,
#         "pressure": 1014,
#         "temp": 63.45,
#         "temp_max": 64,
#         "temp_min": 63
#     },
#     "name": "Hermanus",
#     "sys": {
#         "country": "ZA",
#         "id": 2006131,
#         "sunrise": 1571025764,
#         "sunset": 1571072113,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 319,
#         "gust": 18.01,
#         "speed": 8.01
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.62,
#         "lon": 147.9
#     },
#     "dt": 1571075406,
#     "id": 2126123,
#     "main": {
#         "grnd_level": 999.2,
#         "humidity": 95,
#         "pressure": 1001,
#         "sea_level": 1001,
#         "temp": 20.21,
#         "temp_max": 20.21,
#         "temp_min": 20.21
#     },
#     "name": "Chokurdakh",
#     "snow": {
#         "3h": 0.376
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571088038,
#         "sunset": 1571120864
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 334,
#         "speed": 9.68
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 68.22,
#         "lon": -135.01
#     },
#     "dt": 1571075465,
#     "id": 5882953,
#     "main": {
#         "humidity": 92,
#         "pressure": 1022,
#         "temp": 21.2,
#         "temp_max": 21.2,
#         "temp_min": 21.2
#     },
#     "name": "Aklavik",
#     "sys": {
#         "country": "CA",
#         "id": 796,
#         "sunrise": 1571068833,
#         "sunset": 1571103072,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -39.94,
#         "lon": 176.59
#     },
#     "dt": 1571075532,
#     "id": 2185329,
#     "main": {
#         "humidity": 90,
#         "pressure": 1009,
#         "temp": 48.99,
#         "temp_max": 48.99,
#         "temp_min": 48.99
#     },
#     "name": "Waipawa",
#     "rain": {
#         "3h": 1.124
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2010964,
#         "sunrise": 1571074033,
#         "sunset": 1571121100,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "gust": 11.01,
#         "speed": 8.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 15.34,
#         "lon": 74.49
#     },
#     "dt": 1571075289,
#     "id": 1273574,
#     "main": {
#         "humidity": 88,
#         "pressure": 1017,
#         "temp": 75.2,
#         "temp_max": 75.2,
#         "temp_min": 75.2
#     },
#     "name": "Vaini",
#     "sys": {
#         "country": "IN",
#         "id": 9229,
#         "sunrise": 1571014400,
#         "sunset": 1571056962,
#         "type": 1
#     },
#     "timezone": 19800,
#     "visibility": 6000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.45,
#         "lon": -114.38
#     },
#     "dt": 1571075278,
#     "id": 6185377,
#     "main": {
#         "humidity": 63,
#         "pressure": 1023,
#         "temp": 30.07,
#         "temp_max": 30.2,
#         "temp_min": 30
#     },
#     "name": "Yellowknife",
#     "sys": {
#         "country": "CA",
#         "id": 1007,
#         "sunrise": 1571062778,
#         "sunset": 1571099227,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.25,
#         "lon": -15.21
#     },
#     "dt": 1571075533,
#     "id": 2630299,
#     "main": {
#         "humidity": 87,
#         "pressure": 1001,
#         "temp": 46.4,
#         "temp_max": 46.4,
#         "temp_min": 46.4
#     },
#     "name": "Hofn",
#     "sys": {
#         "country": "IS",
#         "id": 76,
#         "sunrise": 1571039216,
#         "sunset": 1571075194,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09n",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 12.75
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 53.51,
#         "lon": 142.97
#     },
#     "dt": 1571075533,
#     "id": 2122614,
#     "main": {
#         "grnd_level": 1001.57,
#         "humidity": 80,
#         "pressure": 1005,
#         "sea_level": 1005,
#         "temp": 29.39,
#         "temp_max": 29.39,
#         "temp_min": 29.39
#     },
#     "name": "Ekhabi",
#     "snow": {
#         "3h": 2.063
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571086406,
#         "sunset": 1571124862
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13n",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 287,
#         "speed": 11.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.08,
#         "lon": -159.32
#     },
#     "dt": 1571075323,
#     "id": 5848280,
#     "main": {
#         "humidity": 74,
#         "pressure": 1016,
#         "temp": 75.94,
#         "temp_max": 80.6,
#         "temp_min": 71.6
#     },
#     "name": "Kapaa",
#     "rain": {},
#     "sys": {
#         "country": "US",
#         "id": 7873,
#         "sunrise": 1571070773,
#         "sunset": 1571112799,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 16.11
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.21,
#         "lon": 138.6
#     },
#     "dt": 1571075368,
#     "id": 2069194,
#     "main": {
#         "grnd_level": 957.73,
#         "humidity": 91,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 45.77,
#         "temp_max": 45.77,
#         "temp_min": 45.77
#     },
#     "name": "Jamestown",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1571083531,
#         "sunset": 1571129834
#     },
#     "timezone": 37800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 65,
#         "speed": 4.47
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 45.18,
#         "lon": 8.4
#     },
#     "dt": 1571075534,
#     "id": 3164565,
#     "main": {
#         "humidity": 82,
#         "pressure": 1019,
#         "temp": 63.23,
#         "temp_max": 66,
#         "temp_min": 59
#     },
#     "name": "Vila",
#     "sys": {
#         "country": "IT",
#         "id": 6734,
#         "sunrise": 1571031610,
#         "sunset": 1571071470,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "speed": 3.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 63
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -30.38,
#         "lon": 153.1
#     },
#     "dt": 1571075535,
#     "id": 2150163,
#     "main": {
#         "humidity": 87,
#         "pressure": 1014,
#         "temp": 59.65,
#         "temp_max": 60.8,
#         "temp_min": 59
#     },
#     "name": "Sawtell",
#     "sys": {
#         "country": "AU",
#         "id": 9521,
#         "sunrise": 1571080199,
#         "sunset": 1571126208,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 2.24
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 67.46,
#         "lon": 153.71
#     },
#     "dt": 1571075535,
#     "id": 2121025,
#     "main": {
#         "grnd_level": 988.5,
#         "humidity": 93,
#         "pressure": 993,
#         "sea_level": 993,
#         "temp": 22.91,
#         "temp_max": 22.91,
#         "temp_min": 22.91
#     },
#     "name": "Srednekolymsk",
#     "snow": {
#         "3h": 1
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571085808,
#         "sunset": 1571120307
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 327,
#         "speed": 20.11
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.48,
#         "lon": -73.76
#     },
#     "dt": 1571075536,
#     "id": 3896218,
#     "main": {
#         "humidity": 25,
#         "pressure": 1018,
#         "temp": 62.6,
#         "temp_max": 62.6,
#         "temp_min": 62.6
#     },
#     "name": "Castro",
#     "sys": {
#         "country": "CL",
#         "id": 8512,
#         "sunrise": 1571047579,
#         "sunset": 1571094931,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 13.87
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 46
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -25.24,
#         "lon": 130.99
#     },
#     "dt": 1571075008,
#     "id": 6355222,
#     "main": {
#         "humidity": 14,
#         "pressure": 1010,
#         "temp": 77,
#         "temp_max": 77,
#         "temp_min": 77
#     },
#     "name": "Yulara",
#     "sys": {
#         "country": "AU",
#         "id": 9487,
#         "sunrise": 1571085742,
#         "sunset": 1571131276,
#         "type": 1
#     },
#     "timezone": 34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 2.24
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.28,
#         "lon": -126.83
#     },
#     "dt": 1571075346,
#     "id": 6089245,
#     "main": {
#         "humidity": 100,
#         "pressure": 1024,
#         "temp": 26.6,
#         "temp_max": 26.6,
#         "temp_min": 26.6
#     },
#     "name": "Norman Wells",
#     "sys": {
#         "country": "CA",
#         "id": 951,
#         "sunrise": 1571066245,
#         "sunset": 1571101734,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13d",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "speed": 2.24
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 64
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 4.87,
#         "lon": -2.24
#     },
#     "dt": 1571075537,
#     "id": 2303611,
#     "main": {
#         "grnd_level": 1002.55,
#         "humidity": 87,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 76.55,
#         "temp_max": 76.55,
#         "temp_min": 76.55
#     },
#     "name": "Axim",
#     "rain": {
#         "3h": 1
#     },
#     "sys": {
#         "country": "GH",
#         "sunrise": 1571032457,
#         "sunset": 1571075730
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 219,
#         "speed": 5.86
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.81,
#         "lon": 109.89
#     },
#     "dt": 1571075537,
#     "id": 1795095,
#     "main": {
#         "grnd_level": 1005.03,
#         "humidity": 76,
#         "pressure": 1020,
#         "sea_level": 1020,
#         "temp": 70.07,
#         "temp_max": 70.07,
#         "temp_min": 70.07
#     },
#     "name": "Mingshui",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1571092597,
#         "sunset": 1571134547
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 44,
#         "speed": 8.55
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 59
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -15,
#         "lon": 22.67
#     },
#     "dt": 1571075538,
#     "id": 915471,
#     "main": {
#         "grnd_level": 894.05,
#         "humidity": 25,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 83.39,
#         "temp_max": 83.39,
#         "temp_min": 83.39
#     },
#     "name": "Kalabo",
#     "sys": {
#         "country": "ZM",
#         "sunrise": 1571025788,
#         "sunset": 1571070443
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 2.88
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -30.17,
#         "lon": -50.22
#     },
#     "dt": 1571075393,
#     "id": 3466165,
#     "main": {
#         "grnd_level": 1022.24,
#         "humidity": 81,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 61.79,
#         "temp_max": 61.79,
#         "temp_min": 61.79
#     },
#     "name": "Cidreira",
#     "rain": {
#         "3h": 0.813
#     },
#     "sys": {
#         "country": "BR",
#         "sunrise": 1571042635,
#         "sunset": 1571088577
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 146,
#         "speed": 22.53
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.81,
#         "lon": -68.31
#     },
#     "dt": 1571075272,
#     "id": 3833367,
#     "main": {
#         "humidity": 61,
#         "pressure": 1023,
#         "temp": 48.2,
#         "temp_max": 48.2,
#         "temp_min": 48.2
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1571045193,
#         "sunset": 1571094702,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 28.86
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 24
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.78,
#         "lon": 147.06
#     },
#     "dt": 1571075336,
#     "id": 2155415,
#     "main": {
#         "humidity": 81,
#         "pressure": 1010,
#         "temp": 48.11,
#         "temp_max": 51.8,
#         "temp_min": 44.01
#     },
#     "name": "New Norfolk",
#     "sys": {
#         "country": "AU",
#         "id": 9545,
#         "sunrise": 1571080924,
#         "sunset": 1571128382,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 320,
#         "speed": 8.05
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.69,
#         "lon": -53.46
#     },
#     "dt": 1571075279,
#     "id": 3443061,
#     "main": {
#         "grnd_level": 1026.79,
#         "humidity": 67,
#         "pressure": 1027,
#         "sea_level": 1027,
#         "temp": 53.69,
#         "temp_max": 53.69,
#         "temp_min": 53.69
#     },
#     "name": "Chuy",
#     "sys": {
#         "country": "UY",
#         "sunrise": 1571043235,
#         "sunset": 1571089532
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 147,
#         "speed": 14.09
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.28,
#         "lon": 115.24
#     },
#     "dt": 1571075491,
#     "id": 1733782,
#     "main": {
#         "humidity": 83,
#         "pressure": 1011,
#         "temp": 79.27,
#         "temp_max": 80.6,
#         "temp_min": 78.01
#     },
#     "name": "Victoria",
#     "sys": {
#         "country": "BN",
#         "id": 9372,
#         "sunrise": 1571090671,
#         "sunset": 1571133905,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "thunderstorm",
#             "icon": "11n",
#             "id": 211,
#             "main": "Thunderstorm"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 3.36
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 97
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.68,
#         "lon": 156.12
#     },
#     "dt": 1571075539,
#     "id": 2121385,
#     "main": {
#         "grnd_level": 972.42,
#         "humidity": 89,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 34.79,
#         "temp_max": 34.79,
#         "temp_min": 34.79
#     },
#     "name": "Severo-Kurilsk",
#     "snow": {
#         "3h": 0.5
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571083003,
#         "sunset": 1571121955
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 247,
#         "speed": 9.87
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.59,
#         "lon": 26.89
#     },
#     "dt": 1571075422,
#     "id": 964432,
#     "main": {
#         "humidity": 84,
#         "pressure": 1016,
#         "temp": 64.99,
#         "temp_max": 64.99,
#         "temp_min": 64.99
#     },
#     "name": "Port Alfred",
#     "sys": {
#         "country": "ZA",
#         "id": 2011314,
#         "sunrise": 1571023973,
#         "sunset": 1571070233,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 254,
#         "gust": 18.01,
#         "speed": 8.01
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.57,
#         "lon": 143.24
#     },
#     "dt": 1571075540,
#     "id": 2120048,
#     "main": {
#         "grnd_level": 883.4,
#         "humidity": 94,
#         "pressure": 1005,
#         "sea_level": 1005,
#         "temp": 4.19,
#         "temp_max": 4.19,
#         "temp_min": 4.19
#     },
#     "name": "Ust-Nera",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571087746,
#         "sunset": 1571123393
#     },
#     "timezone": 36000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 274,
#         "speed": 2.44
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 96
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -35.1,
#         "lon": 173.78
#     },
#     "dt": 1571075540,
#     "id": 2189343,
#     "main": {
#         "humidity": 100,
#         "pressure": 985,
#         "temp": 58.46,
#         "temp_max": 59,
#         "temp_min": 57.99
#     },
#     "name": "Kaeo",
#     "rain": {
#         "3h": 0.688
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2016422,
#         "sunrise": 1571074994,
#         "sunset": 1571121489,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 351,
#         "speed": 31.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.53,
#         "lon": 148.16
#     },
#     "dt": 1571075097,
#     "id": 2167426,
#     "main": {
#         "humidity": 82,
#         "pressure": 1013,
#         "temp": 67.46,
#         "temp_max": 68,
#         "temp_min": 66.99
#     },
#     "name": "Emerald",
#     "sys": {
#         "country": "AU",
#         "id": 9524,
#         "sunrise": 1571081699,
#         "sunset": 1571127078,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 8.96,
#         "lon": 38.73
#     },
#     "dt": 1571075404,
#     "id": 344979,
#     "main": {
#         "humidity": 51,
#         "pressure": 1026,
#         "temp": 59,
#         "temp_max": 59,
#         "temp_min": 59
#     },
#     "name": "Lebu",
#     "sys": {
#         "country": "ET",
#         "id": 2453,
#         "sunrise": 1571022763,
#         "sunset": 1571065761,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 16.11
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 92
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 53.08,
#         "lon": 82.34
#     },
#     "dt": 1571075541,
#     "id": 1493722,
#     "main": {
#         "grnd_level": 985.01,
#         "humidity": 32,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 61.25,
#         "temp_max": 61.25,
#         "temp_min": 61.25
#     },
#     "name": "Rebrikha",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571100937,
#         "sunset": 1571139430
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 192,
#         "speed": 17.05
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.8,
#         "lon": -139.03
#     },
#     "dt": 1571075484,
#     "id": 4020109,
#     "main": {
#         "grnd_level": 1013.46,
#         "humidity": 75,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 79.61,
#         "temp_max": 79.61,
#         "temp_min": 79.61
#     },
#     "name": "Atuona",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1571064771,
#         "sunset": 1571109063
#     },
#     "timezone": -34200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 17.47
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 52.04,
#         "lon": 76.93
#     },
#     "dt": 1571075541,
#     "id": 1524298,
#     "main": {
#         "grnd_level": 996.69,
#         "humidity": 48,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 54.77,
#         "temp_max": 54.77,
#         "temp_min": 54.77
#     },
#     "name": "Aksu",
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1571015640,
#         "sunset": 1571054550
#     },
#     "timezone": 21600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 212,
#         "speed": 10.97
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 69.44,
#         "lon": -133.03
#     },
#     "dt": 1571075341,
#     "id": 6170031,
#     "main": {
#         "humidity": 85,
#         "pressure": 1021,
#         "temp": 21.2,
#         "temp_max": 21.2,
#         "temp_min": 21.2
#     },
#     "name": "Tuktoyaktuk",
#     "sys": {
#         "country": "CA",
#         "id": 942,
#         "sunrise": 1571068666,
#         "sunset": 1571102289,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 12.75
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 41
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.53,
#         "lon": 20.04
#     },
#     "dt": 1571075375,
#     "id": 1015776,
#     "main": {
#         "humidity": 52,
#         "pressure": 1015,
#         "temp": 64.18,
#         "temp_max": 64.4,
#         "temp_min": 64
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "id": 1966,
#         "sunrise": 1571025567,
#         "sunset": 1571071927,
#         "type": 1
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 320,
#         "speed": 9.17
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39,
#         "lon": -77.4
#     },
#     "dt": 1571075542,
#     "id": 4787534,
#     "main": {
#         "humidity": 33,
#         "pressure": 1017,
#         "temp": 71.85,
#         "temp_max": 75,
#         "temp_min": 69.01
#     },
#     "name": "Sterling",
#     "sys": {
#         "country": "US",
#         "id": 4624,
#         "sunrise": 1571051860,
#         "sunset": 1571092397,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 290,
#         "speed": 9.17
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66.32,
#         "lon": -179.17
#     },
#     "dt": 1571075542,
#     "id": 4031742,
#     "main": {
#         "grnd_level": 941.52,
#         "humidity": 97,
#         "pressure": 996,
#         "sea_level": 996,
#         "temp": 25.61,
#         "temp_max": 25.61,
#         "temp_min": 25.61
#     },
#     "name": "Egvekinot",
#     "snow": {
#         "3h": 2.5
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1571165641,
#         "sunset": 1571200230
#     },
#     "timezone": 43200,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13n",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 73,
#         "speed": 4.58
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.93,
#         "lon": 18.42
#     },
#     "dt": 1571075311,
#     "id": 3369157,
#     "main": {
#         "humidity": 68,
#         "pressure": 1019,
#         "temp": 64.04,
#         "temp_max": 64.99,
#         "temp_min": 63
#     },
#     "name": "Cape Town",
#     "sys": {
#         "country": "ZA",
#         "id": 1899,
#         "sunrise": 1571025987,
#         "sunset": 1571072284,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
# ...
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 102,
#         "speed": 1.72
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 48.72,
#         "lon": -86.38
#     },
#     "dt": 1571075723,
#     "id": 6065867,
#     "main": {
#         "humidity": 80,
#         "pressure": 1007,
#         "temp": 41,
#         "temp_max": 41,
#         "temp_min": 41
#     },
#     "name": "Marathon",
#     "sys": {
#         "country": "CA",
#         "id": 916,
#         "sunrise": 1571054621,
#         "sunset": 1571093946,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.86,
#         "lon": -147.8
#     },
#     "dt": 1571075723,
#     "id": 5859699,
#     "main": {
#         "humidity": 78,
#         "pressure": 1016,
#         "temp": 20.91,
#         "temp_max": 28.4,
#         "temp_min": 15.8
#     },
#     "name": "College",
#     "sys": {
#         "country": "US",
#         "id": 7683,
#         "sunrise": 1571071212,
#         "sunset": 1571106831,
#         "type": 1
#     },
#     "timezone": -28800,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "speed": 5.82
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 48
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -5.74,
#         "lon": -78.43
#     },
#     "dt": 1571075724,
#     "id": 3699078,
#     "main": {
#         "grnd_level": 905.81,
#         "humidity": 46,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 81.59,
#         "temp_max": 81.59,
#         "temp_min": 81.59
#     },
#     "name": "Cajaruro",
#     "sys": {
#         "country": "PE",
#         "sunrise": 1571050376,
#         "sunset": 1571094375
#     },
#     "timezone": -18000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 66,
#         "speed": 3.03
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -19.06,
#         "lon": -169.92
#     },
#     "dt": 1571075412,
#     "id": 4036284,
#     "main": {
#         "humidity": 88,
#         "pressure": 1012,
#         "temp": 71.6,
#         "temp_max": 71.6,
#         "temp_min": 71.6
#     },
#     "name": "Alofi",
#     "sys": {
#         "country": "NU",
#         "id": 7306,
#         "sunrise": 1571071830,
#         "sunset": 1571116829,
#         "type": 1
#     },
#     "timezone": -39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.66,
#         "lon": -17.92
#     },
#     "dt": 1571075337,
#     "id": 2514651,
#     "main": {
#         "humidity": 68,
#         "pressure": 1021,
#         "temp": 68.54,
#         "temp_max": 71.6,
#         "temp_min": 66
#     },
#     "name": "Los Llanos de Aridane",
#     "sys": {
#         "country": "ES",
#         "id": 2377,
#         "sunrise": 1571037090,
#         "sunset": 1571078621,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 9.17
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 44.18,
#         "lon": 66.74
#     },
#     "dt": 1571075725,
#     "id": 1524801,
#     "main": {
#         "grnd_level": 1007.49,
#         "humidity": 33,
#         "pressure": 1025,
#         "sea_level": 1025,
#         "temp": 59.27,
#         "temp_max": 59.27,
#         "temp_min": 59.27
#     },
#     "name": "Shieli",
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1571017534,
#         "sunset": 1571057547
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 229,
#         "speed": 16.71
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 36.09,
#         "lon": 120.35
#     },
#     "dt": 1571075725,
#     "id": 1797929,
#     "main": {
#         "humidity": 70,
#         "pressure": 1035,
#         "temp": 42.8,
#         "temp_max": 42.8,
#         "temp_min": 42.8
#     },
#     "name": "Qingdao",
#     "sys": {
#         "country": "CN",
#         "id": 9657,
#         "sunrise": 1571090674,
#         "sunset": 1571131450,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "speed": 6.71
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 58
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -11.56,
#         "lon": -77.27
#     },
#     "dt": 1571075726,
#     "id": 3944399,
#     "main": {
#         "humidity": 60,
#         "pressure": 1014,
#         "temp": 71.6,
#         "temp_max": 71.6,
#         "temp_min": 71.6
#     },
#     "name": "Chancay",
#     "sys": {
#         "country": "PE",
#         "id": 8682,
#         "sunrise": 1571049891,
#         "sunset": 1571094304,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 10.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.47,
#         "lon": -16.25
#     },
#     "dt": 1571075726,
#     "id": 2511174,
#     "main": {
#         "humidity": 64,
#         "pressure": 1022,
#         "temp": 70.52,
#         "temp_max": 75.2,
#         "temp_min": 66
#     },
#     "name": "Santa Cruz de Tenerife",
#     "sys": {
#         "country": "ES",
#         "id": 2374,
#         "sunrise": 1571036681,
#         "sunset": 1571078228,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 13.87
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.56,
#         "lon": 164.28
#     },
#     "dt": 1571075726,
#     "id": 2140558,
#     "main": {
#         "grnd_level": 976.85,
#         "humidity": 83,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 59.45,
#         "temp_max": 59.45,
#         "temp_min": 59.45
#     },
#     "name": "Koumac",
#     "sys": {
#         "country": "NC",
#         "sunrise": 1571077958,
#         "sunset": 1571123083
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 148,
#         "speed": 3.81
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -19.93,
#         "lon": -60.77
#     },
#     "dt": 1571075727,
#     "id": 3867427,
#     "main": {
#         "grnd_level": 982.1,
#         "humidity": 37,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 92.57,
#         "temp_max": 92.57,
#         "temp_min": 92.57
#     },
#     "name": "Mayor Pablo Lagerenza",
#     "sys": {
#         "country": "PY",
#         "sunrise": 1571045614,
#         "sunset": 1571090662
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 232,
#         "speed": 8.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 36.89,
#         "lon": 136.78
#     },
#     "dt": 1571075727,
#     "id": 1863341,
#     "main": {
#         "humidity": 100,
#         "pressure": 1022,
#         "temp": 57.69,
#         "temp_max": 59,
#         "temp_min": 55.4
#     },
#     "name": "Hakui",
#     "sys": {
#         "country": "JP",
#         "id": 8017,
#         "sunrise": 1571086769,
#         "sunset": 1571127470,
#         "type": 1
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 70,
#         "speed": 4.7
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 43
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 11.01,
#         "lon": 29.72
#     },
#     "dt": 1571075727,
#     "id": 373141,
#     "main": {
#         "grnd_level": 949.4,
#         "humidity": 76,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 76.55,
#         "temp_max": 76.55,
#         "temp_min": 76.55
#     },
#     "name": "Kaduqli",
#     "rain": {
#         "3h": 0.188
#     },
#     "sys": {
#         "country": "SD",
#         "sunrise": 1571024995,
#         "sunset": 1571067853
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 136,
#         "speed": 3.85
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.93,
#         "lon": -79.54
#     },
#     "dt": 1571075728,
#     "id": 5992211,
#     "main": {
#         "humidity": 43,
#         "pressure": 1015,
#         "temp": 53.1,
#         "temp_max": 55.99,
#         "temp_min": 48
#     },
#     "name": "King City",
#     "sys": {
#         "country": "CA",
#         "id": 1002,
#         "sunrise": 1571052656,
#         "sunset": 1571092628,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "gust": 23.04,
#         "speed": 14.99
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 29.59,
#         "lon": 105.06
#     },
#     "dt": 1571075728,
#     "id": 1799491,
#     "main": {
#         "grnd_level": 984.9,
#         "humidity": 89,
#         "pressure": 1025,
#         "sea_level": 1025,
#         "temp": 62.33,
#         "temp_max": 62.33,
#         "temp_min": 62.33
#     },
#     "name": "Neijiang",
#     "rain": {
#         "3h": 0.438
#     },
#     "sys": {
#         "country": "CN",
#         "sunrise": 1571094039,
#         "sunset": 1571135423
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 204,
#         "speed": 2.46
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 95
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.38,
#         "lon": 121.38
#     },
#     "dt": 1571075729,
#     "id": 1791464,
#     "main": {
#         "humidity": 71,
#         "pressure": 1026,
#         "temp": 69.49,
#         "temp_max": 72,
#         "temp_min": 66
#     },
#     "name": "Wenling",
#     "rain": {
#         "3h": 0.562
#     },
#     "sys": {
#         "country": "CN",
#         "id": 2020550,
#         "sunrise": 1571090068,
#         "sunset": 1571131562,
#         "type": 3
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 12,
#         "speed": 19.12
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 14
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -7.91,
#         "lon": 39.67
#     },
#     "dt": 1571075729,
#     "id": 157429,
#     "main": {
#         "grnd_level": 1012.6,
#         "humidity": 80,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 79.07,
#         "temp_max": 79.07,
#         "temp_min": 79.07
#     },
#     "name": "Kilindoni",
#     "sys": {
#         "country": "TZ",
#         "sunrise": 1571021965,
#         "sunset": 1571066108
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 108,
#         "speed": 11.28
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 45.62,
#         "lon": -61.36
#     },
#     "dt": 1571075729,
#     "id": 6111867,
#     "main": {
#         "humidity": 81,
#         "pressure": 1019,
#         "temp": 55.24,
#         "temp_max": 57,
#         "temp_min": 53.01
#     },
#     "name": "Port Hawkesbury",
#     "rain": {},
#     "sys": {
#         "country": "CA",
#         "id": 876,
#         "sunrise": 1571048396,
#         "sunset": 1571088163,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 14484,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "gust": 17.22,
#         "speed": 11.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 52.47,
#         "lon": 1.45
#     },
#     "dt": 1571075730,
#     "id": 2656067,
#     "main": {
#         "humidity": 93,
#         "pressure": 1003,
#         "temp": 57.96,
#         "temp_max": 60.01,
#         "temp_min": 55
#     },
#     "name": "Broome",
#     "sys": {
#         "country": "GB",
#         "id": 1467,
#         "sunrise": 1571033814,
#         "sunset": 1571072602,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 8000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 6.93
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 69
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -3.38,
#         "lon": -68.87
#     },
#     "dt": 1571075730,
#     "id": 3662252,
#     "main": {
#         "grnd_level": 999.19,
#         "humidity": 81,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 82.85,
#         "temp_max": 82.85,
#         "temp_min": 82.85
#     },
#     "name": "Sao Paulo de Olivenca",
#     "rain": {
#         "3h": 3.188
#     },
#     "sys": {
#         "country": "BR",
#         "sunrise": 1571048164,
#         "sunset": 1571091999
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 343,
#         "speed": 3.05
#     }
# }

# %%
# Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
    # Try statement to append calls where value is found 
    # Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} of set1 | {city_record}")
                
        # Increase counter by one 
        record= record + 1
        
        # Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
    # If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 1 of set1 | Yellowknife
# Processing Record 2 of set1 | Hofn
# Processing Record 3 of set1 | Ekhabi
# Processing Record 4 of set1 | Kapaa
# Processing Record 5 of set1 | Jamestown
# City not found. Skipping...
# Processing Record 6 of set1 | Vila
# Processing Record 7 of set1 | Sawtell
# City not found. Skipping...
# Processing Record 8 of set1 | Srednekolymsk
# Processing Record 9 of set1 | Castro
# City not found. Skipping...
# Processing Record 10 of set1 | Yulara
# Processing Record 11 of set1 | Norman Wells
# Processing Record 12 of set1 | Axim
# Processing Record 13 of set1 | Mingshui
# City not found. Skipping...
# Processing Record 14 of set1 | Kalabo
# Processing Record 15 of set1 | Cidreira
# Processing Record 16 of set1 | Ushuaia
# Processing Record 17 of set1 | New Norfolk
# Processing Record 18 of set1 | Chuy
# Processing Record 19 of set1 | Victoria
# Processing Record 20 of set1 | Severo-Kurilsk
# Processing Record 21 of set1 | Port Alfred
# Processing Record 22 of set1 | Ust-Nera
# Processing Record 23 of set1 | Kaeo
# Processing Record 24 of set1 | Emerald
# Processing Record 25 of set1 | Lebu
# Processing Record 26 of set1 | Rebrikha
# Processing Record 27 of set1 | Atuona
# Processing Record 28 of set1 | Aksu
# Processing Record 29 of set1 | Tuktoyaktuk
# Processing Record 30 of set1 | Bredasdorp
# Processing Record 31 of set1 | Sterling
# Processing Record 32 of set1 | Egvekinot
# Processing Record 33 of set1 | Cape Town
# Processing Record 34 of set1 | Mudon
# Processing Record 35 of set1 | Saint-Pierre
# Processing Record 36 of set1 | Ribeira Grande
# Processing Record 37 of set1 | Kruisfontein
# Processing Record 38 of set1 | Broken Hill
# Processing Record 39 of set1 | Cherskiy
# Processing Record 40 of set1 | Srivardhan
# Processing Record 41 of set1 | Gat
# Processing Record 42 of set1 | Leningradskiy
# Processing Record 43 of set1 | Mar del Plata
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 44 of set1 | Albany
# City not found. Skipping...
# Processing Record 45 of set1 | Mareeba
# Processing Record 46 of set1 | Tromso
# Processing Record 47 of set1 | Quatre Cocos
# Processing Record 48 of set1 | Clyde River
# Processing Record 49 of set1 | Tagbac
# Processing Record 50 of set1 | Hobart
# Processing Record 51 of set1 | Sibu
# Processing Record 52 of set1 | Praia da Vitoria
# Processing Record 53 of set1 | Qaanaaq
# Processing Record 54 of set1 | Tyup
# Processing Record 55 of set1 | Magadi
# Processing Record 56 of set1 | Mbala
# Processing Record 57 of set1 | Kaitangata
# City not found. Skipping...
# Processing Record 58 of set1 | Carnarvon
# Processing Record 59 of set1 | Tagusao
# Processing Record 60 of set1 | Aswan
# Processing Record 61 of set1 | Kodiak
# Processing Record 62 of set1 | Tigil
# Processing Record 63 of set1 | Monrovia
# Processing Record 64 of set1 | Guerrero Negro
# City not found. Skipping...
# Processing Record 65 of set1 | Hasaki
# Processing Record 66 of set1 | La Libertad
# Processing Record 67 of set1 | Lagoa
# Processing Record 68 of set1 | Tuatapere
# Processing Record 69 of set1 | Segezha
# Processing Record 70 of set1 | Ilo
# Processing Record 71 of set1 | Mayumba
# Processing Record 72 of set1 | Baft
# Processing Record 73 of set1 | Magan
# Processing Record 74 of set1 | Madimba
# Processing Record 75 of set1 | Surt
# Processing Record 76 of set1 | Esperance
# Processing Record 77 of set1 | Haverfordwest
# Processing Record 78 of set1 | Kahului
# Processing Record 79 of set1 | Tamiahua
# Processing Record 80 of set1 | Matara
# City not found. Skipping...
# Processing Record 81 of set1 | Fare
# Processing Record 82 of set1 | Mitu
# Processing Record 83 of set1 | Hamilton
# Processing Record 84 of set1 | Jefferson City
# Processing Record 85 of set1 | Klaksvik
# Processing Record 86 of set1 | Lompoc
# Processing Record 87 of set1 | Nikolskoye
# City not found. Skipping...
# Processing Record 88 of set1 | North Bend
# Processing Record 89 of set1 | Barrow
# Processing Record 90 of set1 | Faanui
# Processing Record 91 of set1 | Mae Ramat
# Processing Record 92 of set1 | Abu Samrah
# Processing Record 93 of set1 | Stokmarknes
# Processing Record 94 of set1 | Beruwala
# Processing Record 95 of set1 | Khatanga
# Processing Record 96 of set1 | Lavrentiya
# Processing Record 97 of set1 | Hilo
# City not found. Skipping...
# Processing Record 98 of set1 | Ahipara
# Processing Record 99 of set1 | Georgetown
# Processing Record 100 of set1 | Biak
# Processing Record 101 of set1 | Mitsamiouli
# Processing Record 102 of set1 | Ende
# Processing Record 103 of set1 | Komsomolskiy
# Processing Record 104 of set1 | Bongandanga
# Processing Record 105 of set1 | Shimanovsk
# Processing Record 106 of set1 | Talnakh
# Processing Record 107 of set1 | Marsh Harbour
# Processing Record 108 of set1 | Mahebourg
# Processing Record 109 of set1 | San Cristobal
# Processing Record 110 of set1 | Gladstone
# Processing Record 111 of set1 | The Valley
# Processing Record 112 of set1 | Saskylakh
# Processing Record 113 of set1 | Terra Santa
# Processing Record 114 of set1 | Puerto Suarez
# Processing Record 115 of set1 | Mount Isa
# Processing Record 116 of set1 | Havoysund
# Processing Record 117 of set1 | Saldanha
# Processing Record 118 of set1 | Dunedin
# Processing Record 119 of set1 | Poum
# Processing Record 120 of set1 | San Juan
# Processing Record 121 of set1 | Buala
# City not found. Skipping...
# Processing Record 122 of set1 | Touros
# Processing Record 123 of set1 | Montijo
# Processing Record 124 of set1 | Port Macquarie
# Processing Record 125 of set1 | Luderitz
# City not found. Skipping...
# Processing Record 126 of set1 | Kensington
# Processing Record 127 of set1 | Namie
# Processing Record 128 of set1 | Upernavik
# Processing Record 129 of set1 | Vrangel
# Processing Record 130 of set1 | Jalu
# Processing Record 131 of set1 | Latung
# Processing Record 132 of set1 | Road Town
# Processing Record 133 of set1 | Ginir
# Processing Record 134 of set1 | Samana
# Processing Record 135 of set1 | Rome
# Processing Record 136 of set1 | Mount Pleasant
# Processing Record 137 of set1 | Torbay
# City not found. Skipping...
# Processing Record 138 of set1 | Abong Mbang
# Processing Record 139 of set1 | Fomboni
# Processing Record 140 of set1 | Matinha
# Processing Record 141 of set1 | Wewak
# Processing Record 142 of set1 | Salalah
# Processing Record 143 of set1 | Dickinson
# Processing Record 144 of set1 | Ancud
# Processing Record 145 of set1 | Sydney
# Processing Record 146 of set1 | Bambous Virieux
# Processing Record 147 of set1 | Inongo
# Processing Record 148 of set1 | Palu
# Processing Record 149 of set1 | Levelland
# Processing Record 150 of set1 | Marzuq
# Processing Record 151 of set1 | Caravelas
# Processing Record 152 of set1 | Murray Bridge
# Processing Record 153 of set1 | Rantoul
# City not found. Skipping...
# Processing Record 154 of set1 | Ibra
# Processing Record 155 of set1 | Souillac
# Processing Record 156 of set1 | Tricase
# Processing Record 157 of set1 | Flinders
# Processing Record 158 of set1 | Luang Prabang
# Processing Record 159 of set1 | Cooma
# Processing Record 160 of set1 | Majene
# Processing Record 161 of set1 | Kirensk
# Processing Record 162 of set1 | Vaitape
# Processing Record 163 of set1 | Barranca
# Processing Record 164 of set1 | Thompson
# Processing Record 165 of set1 | Berdigestyakh
# City not found. Skipping...
# Processing Record 166 of set1 | Pisco
# Processing Record 167 of set1 | Noisy-le-Grand
# Processing Record 168 of set1 | Kenai
# City not found. Skipping...
# Processing Record 169 of set1 | Pangnirtung
# City not found. Skipping...
# Processing Record 170 of set1 | Ponta do Sol
# Processing Record 171 of set1 | Micheweni
# Processing Record 172 of set1 | Kununurra
# Processing Record 173 of set1 | Fairbanks
# Processing Record 174 of set1 | Qasigiannguit
# Processing Record 175 of set1 | Taoudenni
# Processing Record 176 of set1 | Toktogul
# City not found. Skipping...
# Processing Record 177 of set1 | Zhigansk
# Processing Record 178 of set1 | Arraial do Cabo
# City not found. Skipping...
# Processing Record 179 of set1 | Suhbaatar
# Processing Record 180 of set1 | Lyudinovo
# Processing Record 181 of set1 | Poitiers
# Processing Record 182 of set1 | Bagotville
# Processing Record 183 of set1 | Chapais
# City not found. Skipping...
# Processing Record 184 of set1 | Le Vauclin
# City not found. Skipping...
# Processing Record 185 of set1 | Balabac
# Processing Record 186 of set1 | Athens
# Processing Record 187 of set1 | Bethel
# Processing Record 188 of set1 | East London
# Processing Record 189 of set1 | Sosnovo-Ozerskoye
# Processing Record 190 of set1 | Yerbogachen
# City not found. Skipping...
# Processing Record 191 of set1 | Sioux Lookout
# City not found. Skipping...
# Processing Record 192 of set1 | Mogadishu
# Processing Record 193 of set1 | Coihaique
# Processing Record 194 of set1 | Neiafu
# Processing Record 195 of set1 | Kaniama
# City not found. Skipping...
# Processing Record 196 of set1 | Sadat
# City not found. Skipping...
# Processing Record 197 of set1 | Magadan
# Processing Record 198 of set1 | Fortuna
# Processing Record 199 of set1 | Snezhnogorsk
# Processing Record 200 of set1 | La Rioja
# Processing Record 201 of set1 | Kempsey
# Processing Record 202 of set1 | Soe
# Processing Record 203 of set1 | Baruun-Urt
# Processing Record 204 of set1 | Vanavara
# Processing Record 205 of set1 | Porto Novo
# Processing Record 206 of set1 | Chicama
# Processing Record 207 of set1 | Plastun
# City not found. Skipping...
# Processing Record 208 of set1 | Casper
# Processing Record 209 of set1 | Anahuac
# Processing Record 210 of set1 | Rockport
# Processing Record 211 of set1 | Narsaq
# Processing Record 212 of set1 | Taltal
# Processing Record 213 of set1 | Yamada
# Processing Record 214 of set1 | Cochrane
# Processing Record 215 of set1 | Iquitos
# Processing Record 216 of set1 | Chara
# Processing Record 217 of set1 | Maldonado
# Processing Record 218 of set1 | Suez
# Processing Record 219 of set1 | Sidi Ali
# Processing Record 220 of set1 | Okhotsk
# City not found. Skipping...
# Processing Record 221 of set1 | Butaritari
# Processing Record 222 of set1 | Japura
# Processing Record 223 of set1 | Castlerea
# Processing Record 224 of set1 | Rio Grande
# Processing Record 225 of set1 | Itoman
# Processing Record 226 of set1 | Nouadhibou
# Processing Record 227 of set1 | Kasongo-Lunda
# Processing Record 228 of set1 | Ust-Tsilma
# Processing Record 229 of set1 | Samarai
# Processing Record 230 of set1 | Airai
# Processing Record 231 of set1 | Grindavik
# Processing Record 232 of set1 | Kilis
# Processing Record 233 of set1 | Kavaratti
# Processing Record 234 of set1 | Amapa
# City not found. Skipping...
# Processing Record 235 of set1 | Fort Nelson
# Processing Record 236 of set1 | Bathsheba
# Processing Record 237 of set1 | Mahibadhoo
# Processing Record 238 of set1 | Saint Anthony
# Processing Record 239 of set1 | Longyearbyen
# Processing Record 240 of set1 | Bambanglipuro
# Processing Record 241 of set1 | Mizoch
# Processing Record 242 of set1 | Marawi
# Processing Record 243 of set1 | Rocha
# Processing Record 244 of set1 | Paldiski
# Processing Record 245 of set1 | Beringovskiy
# Processing Record 246 of set1 | Sai Buri
# Processing Record 247 of set1 | Beba
# Processing Record 248 of set1 | Bafq
# Processing Record 249 of set1 | Nome
# City not found. Skipping...
# Processing Record 250 of set1 | Palana
# City not found. Skipping...
# Processing Record 251 of set1 | Pundaguitan
# City not found. Skipping...
# Processing Record 252 of set1 | Port Elizabeth
# Processing Record 253 of set1 | Laguna
# City not found. Skipping...
# Processing Record 254 of set1 | Berlevag
# Processing Record 255 of set1 | Maningrida
# Processing Record 256 of set1 | Severobaykalsk
# Processing Record 257 of set1 | Uyuni
# Processing Record 258 of set1 | Wajir
# Processing Record 259 of set1 | Ust-Kut
# Processing Record 260 of set1 | Kinablangan
# Processing Record 261 of set1 | Ures
# Processing Record 262 of set1 | Saint-Philippe
# Processing Record 263 of set1 | Les Cayes
# Processing Record 264 of set1 | Zabol
# Processing Record 265 of set1 | Ilula
# Processing Record 266 of set1 | Ilulissat
# Processing Record 267 of set1 | El Retorno
# Processing Record 268 of set1 | Iralaya
# Processing Record 269 of set1 | Dukat
# Processing Record 270 of set1 | Bam
# Processing Record 271 of set1 | Pitkyaranta
# Processing Record 272 of set1 | Benito Juarez
# Processing Record 273 of set1 | Vermilion
# Processing Record 274 of set1 | Emba
# Processing Record 275 of set1 | Nuevo Progreso
# Processing Record 276 of set1 | Piacabucu
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 277 of set1 | Plouzane
# Processing Record 278 of set1 | Salto
# Processing Record 279 of set1 | Kavieng
# Processing Record 280 of set1 | Umba
# City not found. Skipping...
# Processing Record 281 of set1 | Leh
# Processing Record 282 of set1 | Jalapa
# Processing Record 283 of set1 | Itarema
# Processing Record 284 of set1 | Sitka
# Processing Record 285 of set1 | Zhezkazgan
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 286 of set1 | Zaria
# Processing Record 287 of set1 | La Union
# Processing Record 288 of set1 | Cairns
# Processing Record 289 of set1 | Mega
# City not found. Skipping...
# Processing Record 290 of set1 | San Patricio
# Processing Record 291 of set1 | Mountain Home
# Processing Record 292 of set1 | Ahuimanu
# Processing Record 293 of set1 | Iqaluit
# Processing Record 294 of set1 | Noumea
# Processing Record 295 of set1 | Faya
# City not found. Skipping...
# Processing Record 296 of set1 | Kyshtovka
# Processing Record 297 of set1 | Cayenne
# Processing Record 298 of set1 | Muyezerskiy
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 299 of set1 | Rio Brilhante
# City not found. Skipping...
# Processing Record 300 of set1 | Traverse City
# Processing Record 301 of set1 | Muzhi
# Processing Record 302 of set1 | Lata
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
